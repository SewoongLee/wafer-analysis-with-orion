# %%
from .common.data_loader import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-dc394d90ad1b> in <module>
# ----> 1 from .common.data_loader import *
#
# ModuleNotFoundError: No module named '__main__.common'; '__main__' is not a package

# %%
N_EPOCH = 1

# %%
import logging;

logging.basicConfig(level=logging.ERROR)
logging.getLogger().setLevel(level=logging.ERROR)

import warnings
warnings.simplefilter("ignore")

# %%
from orion.data import load_signal

signal_path = 'S-1'

data = load_signal(signal_path)
data.head()
# Out:
#     timestamp     value
# 0  1222819200 -0.366359
# 1  1222840800 -0.394108
# 2  1222862400  0.403625
# 3  1222884000 -0.362759
# 4  1222905600 -0.370746

# %%
data
# Out:
#         timestamp     value
# 0      1222819200 -0.366359
# 1      1222840800 -0.394108
# 2      1222862400  0.403625
# 3      1222884000 -0.362759
# 4      1222905600 -0.370746
# ...           ...       ...
# 10144  1441929600 -0.334147
# 10145  1441951200  1.000000
# 10146  1441972800 -0.275623
# 10147  1441994400  1.000000
# 10148  1442016000 -0.345648
#
# [10149 rows x 2 columns]

# %%
data.value[:200].plot()
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.plot(data.timestamp, data.value)

# %%
from orion.analysis import analyze

hyperparameters = {
    'keras.Sequential.LSTMTimeSeriesRegressor#1': {
        'epochs': N_EPOCH,
        'verbose': True
    }
}

pipeline = 'lstm_dynamic_threshold'

anomalies = analyze(pipeline, data, hyperparams=hyperparameters)
anomalies
# Out:
# Epoch 1/5
# 124/124 [==============================] - 28s 222ms/step - loss: 0.1953 - mse: 0.1953 - val_loss: 0.3019 - val_mse: 0.3019
# Epoch 2/5
# 124/124 [==============================] - 27s 221ms/step - loss: 0.1931 - mse: 0.1931 - val_loss: 0.3026 - val_mse: 0.3026
# Epoch 3/5
# 124/124 [==============================] - 27s 217ms/step - loss: 0.1902 - mse: 0.1902 - val_loss: 0.2931 - val_mse: 0.2931
# Epoch 4/5
# 124/124 [==============================] - 27s 218ms/step - loss: 0.1884 - mse: 0.1884 - val_loss: 0.2550 - val_mse: 0.2550
# Epoch 5/5
# ...
# 155/155 [==============================] - 6s 37ms/step
#         start         end     score
# 0  1228219200  1229472000  0.613260
# 1  1401775200  1405857600  0.120012

# %%
import pandas as pd
wafer_train = pd.read_table("./datasets/UCRArchive_2018/Wafer/Wafer_TRAIN.tsv", header=None)
wafer_train
# Out:
#      0         1         2         3         4         5         6    \
# 0      1 -1.602294 -1.670823 -1.693666 -1.699377 -1.699377 -1.703660
# 1      1  1.084591  1.084591  1.084591  1.065308  1.065308  1.065308
# 2      1  0.362689  0.362689  0.362689  0.393316  0.362689  0.362689
# 3      1 -1.094523 -1.094523 -1.094523 -1.096732 -1.094523 -1.096732
# 4      1 -1.103761 -1.103761 -1.103761 -1.103761 -1.103761 -1.103761
# ..   ...       ...       ...       ...       ...       ...       ...
# 995    1 -1.621709 -1.644240 -1.652689 -1.658322 -1.658322 -1.662546
# 996    1  0.813520  0.813520  0.813520  0.813520  0.813520  0.813520
# 997   -1 -0.832885 -0.977293 -0.923421 -0.953684 -0.936716 -0.946148
# 998    1  0.930389  0.930389  0.930389  0.930389  0.930389  0.930389
# 999    1 -1.148181 -1.150335 -1.148181 -1.148181 -1.148181 -1.148181
#
#           7         8         9    ...       143       144       145  \
# ...

# %%
wafer_train_y = wafer_train[0]
wafer_train_y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 995    1
# 996    1
# 997   -1
# 998    1
# 999    1
# Name: 0, Length: 1000, dtype: int64

# %%
wafer_train_x = wafer_train.drop(columns=[0])
wafer_train_x
# Out:
#           1         2         3         4         5         6         7    \
# 0   -1.602294 -1.670823 -1.693666 -1.699377 -1.699377 -1.703660 -1.703660
# 1    1.084591  1.084591  1.084591  1.065308  1.065308  1.065308  1.065308
# 2    0.362689  0.362689  0.362689  0.393316  0.362689  0.362689  0.362689
# 3   -1.094523 -1.094523 -1.094523 -1.096732 -1.094523 -1.096732 -1.094523
# 4   -1.103761 -1.103761 -1.103761 -1.103761 -1.103761 -1.103761 -1.103761
# ..        ...       ...       ...       ...       ...       ...       ...
# 995 -1.621709 -1.644240 -1.652689 -1.658322 -1.658322 -1.662546 -1.658322
# 996  0.813520  0.813520  0.813520  0.813520  0.813520  0.813520  0.813520
# 997 -0.832885 -0.977293 -0.923421 -0.953684 -0.936716 -0.946148 -0.943889
# 998  0.930389  0.930389  0.930389  0.930389  0.930389  0.930389  0.930389
# 999 -1.148181 -1.150335 -1.148181 -1.148181 -1.148181 -1.148181 -1.148181
#
#           8         9         10   ...       143       144       145  \
# ...

# %%
plt.plot(wafer_train_x.loc[0])

# %%
sample_x = wafer_train_x.loc[0]

# %%
sample_wafer = pd.DataFrame({
    "timestamp": range(1, len(sample_x)+1),
    "value": sample_x,
})
sample_wafer
# Out:
#      timestamp     value
# 1            1 -1.602294
# 2            2 -1.670823
# 3            3 -1.693666
# 4            4 -1.699377
# 5            5 -1.699377
# ..         ...       ...
# 148        148 -1.145432
# 149        149 -1.145432
# 150        150 -1.145432
# 151        151 -1.145432
# 152        152 -1.145432
#
# [152 rows x 2 columns]

# %%
from orion.analysis import analyze

hyperparameters = {
    'keras.Sequential.LSTMTimeSeriesRegressor#1': {
        'epochs': N_EPOCH,
        'verbose': True
    }
}

pipeline = 'lstm_dynamic_threshold'

anomalies = analyze(pipeline, sample_wafer, hyperparams=hyperparameters)
anomalies
# Out:
# ERROR:mlblocks.mlpipeline:Exception caught fitting MLBlock keras.Sequential.LSTMTimeSeriesRegressor#1
# Traceback (most recent call last):
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlblocks\mlpipeline.py", line 644, in _fit_block
#     block.fit(**fit_args)
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlblocks\mlblock.py", line 311, in fit
#     getattr(self.instance, self.fit_method)(**fit_kwargs)
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlstars\adapters\keras.py", line 104, in fit
#     self._augment_hyperparameters(X, 'input', kwargs)
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlstars\adapters\keras.py", line 90, in _augment_hyperparameters
#     shape = np.asarray(X)[0].shape
# IndexError: index 0 is out of bounds for axis 0 with size 0
# ---------------------------------------------------------------------------
# ...

# %%
num = 10000

# %%
import numpy as np
import matplotlib.pyplot as plt
value = np.sin(np.linspace(start=0, stop=10, num=num))
plt.plot(value)

# %%
df = pd.DataFrame({
    "timestamp": range(1222819200, 1222819200+num),
    "value": value
})
df
# Out:
#        timestamp     value
# 0     1222819200  0.000000
# 1     1222819201  0.001000
# 2     1222819202  0.002000
# 3     1222819203  0.003000
# 4     1222819204  0.004000
# ...          ...       ...
# 9995  1222829195 -0.540660
# 9996  1222829196 -0.541501
# 9997  1222829197 -0.542342
# 9998  1222829198 -0.543182
# 9999  1222829199 -0.544021
#
# [10000 rows x 2 columns]

# %%
from orion.analysis import analyze

hyperparameters = {
    'keras.Sequential.LSTMTimeSeriesRegressor#1': {
        'epochs': 5,
        'verbose': True
    }
}

pipeline = 'lstm_dynamic_threshold'

anomalies = analyze(pipeline, df, hyperparams=hyperparameters)
anomalies
# Out:
# ERROR:mlblocks.mlpipeline:Exception caught fitting MLBlock keras.Sequential.LSTMTimeSeriesRegressor#1
# Traceback (most recent call last):
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlblocks\mlpipeline.py", line 644, in _fit_block
#     block.fit(**fit_args)
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlblocks\mlblock.py", line 311, in fit
#     getattr(self.instance, self.fit_method)(**fit_kwargs)
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlstars\adapters\keras.py", line 104, in fit
#     self._augment_hyperparameters(X, 'input', kwargs)
#   File "c:\users\sewoo\appdata\local\programs\python\python36\lib\site-packages\mlstars\adapters\keras.py", line 90, in _augment_hyperparameters
#     shape = np.asarray(X)[0].shape
# IndexError: index 0 is out of bounds for axis 0 with size 0
# ---------------------------------------------------------------------------
# ...

# %%
orion.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-a326473dc719> in <module>
# ----> 1 orion.__version__
#
# NameError: name 'orion' is not defined
